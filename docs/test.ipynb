# %% [markdown]
# # Benefits Cliff Estimator Notebook
#
# Fitz Koch
# 2026-04-25

# %%
import sys, os
from pathlib import Path

_project_root = Path.cwd()
while not (_project_root / "src").exists():
    _project_root = _project_root.parent
os.chdir(_project_root)
